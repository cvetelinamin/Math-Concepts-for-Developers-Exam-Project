# %% [markdown]
# # Credit Risk Scoring System

# %% [markdown]
# ## 1.What is credit risk and why is it important to create an accurate model?

# %% [markdown]
# Credit risk refers to the possibility that a borrower will fail to repay a loan or meet contractual obligations, causing financial losses or gains to the lender. It is crucial for lenders and financial institutions to assess this risk accurately to make informed lending decisions.
#
# An accurate credit risk model helps:
#
# Minimize losses by identifying high-risk borrowers.
# Optimize loan approval processes, ensuring that credit is extended to those who are likely to repay.
# Improve profitability by balancing the risk and reward of lending decisions.
#
# ###https://medium.com/@danrlei.diegues_91903/credit-risk-modeling-in-python-e9b2379ebeb0

# %% [markdown]
# When assessing customer credit risk, it is crucial to consider several vital features that can impact the creditworthiness of borrowers in credit risk prediction.
#
# 1. **Basic Features**<br>
# a. **Loan amount:** The loan is a critical factor in determining credit risk. Generally, the more significant the loan amount, the higher the risk.<br>
# b. **Loan term:** The length of the loan term is another vital consideration. Longer loan terms may be riskier because the borrower is more likely to default over the extended repayment period.<br>
# c. **Interest rate:** The interest rate is a critical factor that impacts the credit risk of the loan. Higher interest rates may make it more challenging for the borrower to repay the loan, and they may be more likely to default.<br>
# d. **Payment history:** The borrower's payment history is crucial in determining credit risk. If the loan applicant has a history of late or missed payments, it suggests that they may have difficulty repaying the loan.<br>
# 2. **Customer default history**<br>
# a. **The number of past defaults:** The number of times a customer has defaulted on a loan or credit product is an essential indicator of credit risk.<br>
# b. **Time since the last default:** The time since the customer's previous default can also be an essential indicator of credit risk.<br>
# 3. **Customer demography**<br>
# a. **Age:** Age is a significant factor in assessing credit risk, as younger customers may need more experience managing finances and have a limited credit history.<br>
# b. **Income:** Income is crucial in determining creditworthiness, as higher-income customers are typically seen as less risky borrowers.<br>
# c. **Employment status:** The employment status of a customer can also impact credit risk. Customers with stable, full-time employment are typically viewed as less risky borrowers than those with part-time or self-employment income.
# 4. **City level features**<br>
# a. **Economic conditions:** Economic conditions in a particular city can significantly impact credit risk. Factors such as unemployment rates, inflation rates, and GDP growth can affect the ability of borrowers to repay their loans.<br>
# b. **Demographics:** Demographic factors such as Age, education level, and income can impact credit risk. For example, younger borrowers or those with lower levels of education may be considered at higher risk due to their lack of financial experience.
# #https://www.almabetter.com/bytes/articles/implementation-of-credit-risk-using-machine-learning-in-python

# %% [markdown]
# ## 2.Credit Risk Components

# %% [markdown]
#  Expected Loss : $$ (EL = PD \times LGD \times EAD) $$
#
# * $PD$ - = Probability of Default
# * $LGD$ - Loss Given Default
# * $EAD$ - Exposure at Default

# %% [markdown]
# ### 2.1 PD (Probability of Default)

# %% [markdown]
# Probability of Default (PD) is a key credit risk metric estimating the likelihood a borrower fails to meet debt obligations within a specific timeframe, usually one year. It provides an estimate of the likelihood that a borrower will be unable to meet its debt obligations.<br>
# It drives credit scoring, pricing, and capital allocation. PD is calculated using historical data, financial metrics, and macroeconomic factors, often distinguishing between Point-in-Time (PIT) and Through-the-Cycle (TTC) estimates.

# %% [markdown]
# The risk of default is derived by analyzing the obligor's capacity to repay the debt in accordance with contractual terms. PD is generally associated with financial characteristics such as inadequate cash flow to service debt, declining revenues or operating margins, high leverage, declining or marginal liquidity, and the inability to successfully implement a business plan. In addition to these quantifiable factors, the borrower's willingness to repay also must be evaluated.<br>
#
# The PD of an obligor not only depends on the risk characteristics of that particular obligor but also the economic environment and the degree to which it affects the obligor. Thus, the information available to estimate PD can be divided into two broad categories -
#
# * Macroeconomic information like house price indices, unemployment, GDP growth rates, etc. - this information remains the same for multiple obligors.
# * Obligor specific information like revenue growth (wholesale), number of times delinquent in the past six months (retail), etc. - this information is specific to a single obligor and can be either static or dynamic in nature. Examples of static characteristics are industry for wholesale loans and origination "loan to value ratio" for retail loans.
#
# A stressed PD is an estimate that the obligor will default over a particular time horizon considering the current obligor specific information, but considering "stressed" macroeconomic factors irrespective of the current state of the economy. The stressed PD of an obligor changes over time depending on the risk characteristics of the obligor, but is not heavily affected by changes in the economic cycle as adverse economic conditions are already factored into the estimate.
#
# Closely related to the concept of stressed and unstressed PD's, the terms through-the-cycle (TTC) or point-in-time (PIT) can be used both in the context of PD as well as rating system. In the context of PD, the stressed PD defined above usually denotes the TTC PD of an obligor whereas the unstressed PD denotes the PIT PD.[6] In the context of rating systems, a PIT rating system assigns each obligor to a bucket such that all obligors in a bucket share similar unstressed PDs while all obligors in a risk bucket assigned by a TTC rating system share similar stressed PDs.
#  #https://en.wikipedia.org/wiki/Probability_of_default <br>

# %% [markdown]
# **Importance of Probability of Default**
# * **Credit Risk Management:** PD helps financial institutions calculate the risk associated with lending money to different borrowers. This helps them in managing their overall credit risk more effectively.
# * **Loan Pricing:** Accurate PD calculation enables lenders to price loans appropriately, ensuring they strike the right balance between risk and return.
# * **Investment Decisions:** Investors use PD to know about the risk of bonds and other debt assets, which helps them to make correct investment decisions.
#
#  **The basic formula (Simple Historical Method) is** $$ PD = \frac{\text{Number of Defaults}}{\text{Total Number of Borrowers}} $$
#  **PD is expressed as a percentage or a decimal. If PD is higher then it indicates a high risk of default. For example, a PD of 5% suggests that there is a 5% chance that the borrower will not be able to pay the loan back within the specified time.<br>
# #https://www.geeksforgeeks.org/maths/probability-of-default/<br>
# **For market-based estimations (Market-Based Method (CDS Spread)), it can be approximated by** $$ PD = \frac{\text{CDS Spread}}{\text{1 - Recovery rate}} $$

# %% [markdown]
# ### 2.2 LGD (Loss Given Default)

# %% [markdown]
# ### 2.3 EAD (Exposure at Risk)
